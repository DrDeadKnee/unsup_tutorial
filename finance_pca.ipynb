# %%
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import yfinance as yf
from sklearn.decomposition import PCA
import pandas as pd

# %%
msft = yf.Ticker("MSFT")
hist = msft.history(period="max")

# %%
allticks = pd.DataFrame()
def add_ticker(allticks, ticker, startdate="2018-01-01"):
    hist = yf.Ticker(ticker).history(start=startdate).reset_index(drop=False)
    slim = hist[["Date", "Open"]]
    slim["ticker"] = ticker
    allticks = allticks.append(slim, ignore_index=True)
    return allticks

allticks = add_ticker(allticks, "MSFT")
add_ticker(allticks, "GOOG")
# Out:
# /tmp/ipykernel_4090/3593424266.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   slim["ticker"] = ticker
# /tmp/ipykernel_4090/3593424266.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allticks = allticks.append(slim, ignore_index=True)
# /tmp/ipykernel_4090/3593424266.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   slim["ticker"] = ticker
# ...

# %%
big_5 = ["BNS","RY.TO","BMO","TD","CM.TO"]
for i in big_5:
    print(yf.Ticker(i).info["shortName"])
# Out:
# Bank Nova Scotia Halifax Pfd 3
# ROYAL BANK OF CANADA
# Bank Of Montreal
# Toronto Dominion Bank (The)
# CANADIAN IMPERIAL BANK OF COMME

# %%
tx.info["shortName"]
# Out:
# 'Bank Nova Scotia Halifax Pfd 3'

# %%
etfs = ["HXT.TO","VCN.TO","XIC.TO"]
for i in etfs:
    print(yf.Ticker(i).info["shortName"])
# Out:
# HORIZONS SP TSX60 INDEX ETF
# VANGUARD FTSE CANADA ALL CAP ID
# iSHARES CORE SP TSX CAPPED COMP

# %%
etfs = pd.read_csv("etfs.csv")
etfs
# Out:
#        ETF
# 0      HXT
# 1      VCN
# 2      XIC
# 3      ZCN
# 4      ZAG
# 5      VAB
# 6      ZDB
# 7      VSB
# 8      HXS
# 9      XUU
# 10     VFV
# 11     ZSP
# 12     VXC
# 13     XAW
# 14     VEE
# 15     VIU
# 16    XEQT
# 17    VEQT
# 18    ZGRO
# 19    XGRO
# 20    VGRO
# 21    VBAL
# 22    XBAL
# 23    ZBAL
# 24    VCNS
# 25    XCNS
# 26    ZCON
# 27    VCIP
# 28    XINC
# 29     XCG
# 30     CDZ
# 31     XDV
# 32     VDY
# 33     XEI
# 34     ZDV
# 35    XDIV
# 36     VRE
# 37     ZRE
# 38     XRE
# 39     RIT
# 40    VRIF
# 41  BTCC.B
# 42   QQC-F
# 43    AVDV
# 44    ZESG

# %%
allticks = pd.DataFrame()
for i in etfs["ETF"]:
    allticks = add_ticker(
        allticks, 
        i + ".TO",
        startdate="2018-01-01"
    )
allticks.ticker.value_counts()
# Out:
# /tmp/ipykernel_4090/3593424266.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   slim["ticker"] = ticker
# /tmp/ipykernel_4090/3593424266.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allticks = allticks.append(slim, ignore_index=True)
# /tmp/ipykernel_4090/3593424266.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   slim["ticker"] = ticker
# ...

# %%
for i in big_5:
    allticks = add_ticker(
        allticks, 
        i,
        startdate="2018-01-01"
    )
allticks.ticker.value_counts()
# Out:
# /tmp/ipykernel_4090/3593424266.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   slim["ticker"] = ticker
# /tmp/ipykernel_4090/3593424266.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allticks = allticks.append(slim, ignore_index=True)
# /tmp/ipykernel_4090/3593424266.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   slim["ticker"] = ticker
# ...

# %%
big_sample = ["GOOG", "AMZN", "AAPL", "MSFT", "JPY", "TSLA"]
for i in big_sample:
    allticks = add_ticker(
        allticks, 
        i,
        startdate="2018-01-01"
    )
allticks.ticker.value_counts()
# Out:
# /tmp/ipykernel_4090/3593424266.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   slim["ticker"] = ticker
# /tmp/ipykernel_4090/3593424266.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allticks = allticks.append(slim, ignore_index=True)
# /tmp/ipykernel_4090/3593424266.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   slim["ticker"] = ticker
# ...

# %%
allticks.to_csv("tickers.csv", index=False)
